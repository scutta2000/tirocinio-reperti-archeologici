# %% [markdown]
# # Obbiettivo
#
# Verificato che l'approccio NN funziona proviamo a stabilire i meta-parametri migliori
#
# # Risultato
#
# I risultati di `GridSearchCV` variano da run a run quindi l'ho svolta piu volte e analizzato i risultati (non ho variato il solver perche dopo alcune run adam era consistentemente il migliore).
#
# Nessun numero di neuroni tra quelli testati sembra essere significativamente migliore ma la funzione di attivazione `tanh` sembra essere mediamente migliore

# %%
import sys; sys.path.insert(0, '..')

# %%
from scripts.get_data import ceramiche_DB
from sklearn.model_selection import GridSearchCV
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.utils import shuffle
import matplotlib.pyplot as plt

from tqdm import tqdm

# %%
X, y = ceramiche_DB()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, stratify=y)
nn = MLPClassifier(max_iter=500, solver='adam', activation = 'identity')
params = dict(
    hidden_layer_sizes  = list(range(2,20)) + [(x,y) for x in range(2,9) for y in range(0,9)],
    # activation          = ['identity', 'logistic', 'tanh', 'relu']
)
# Out:
# ..\dati_ceramiche_classi.xlsx
# d:\Documenti\GitHub\tirocinio\tirocinio-venv\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
clf = GridSearchCV(estimator=nn, param_grid=params, cv=5, scoring='accuracy', verbose = 0, n_jobs = -1)

# %%
## Attenzione richiede molto tempo per essere eseguito (circa 15 min sulla mia macchina)
import warnings

params = []
with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    for i in tqdm(range(75)):
        X, y = shuffle(X, y)
        trained = clf.fit(X, y)
        print(trained.best_params_, trained.best_score_)
        params.append((trained.best_params_, trained.best_score_))
# Out:
#   1%|▏         | 1/75 [00:24<29:42, 24.09s/it]{'hidden_layer_sizes': (3, 7)} 0.9822134387351777
#   3%|▎         | 2/75 [00:45<27:41, 22.77s/it]{'hidden_layer_sizes': (6, 3)} 0.9826086956521738
#   4%|▍         | 3/75 [01:12<29:37, 24.68s/it]{'hidden_layer_sizes': (4, 8)} 0.9913043478260869
#   5%|▌         | 4/75 [01:36<28:52, 24.40s/it]{'hidden_layer_sizes': 10} 0.9826086956521738
#   7%|▋         | 5/75 [02:08<31:26, 26.94s/it]{'hidden_layer_sizes': 4} 0.990909090909091
#   8%|▊         | 6/75 [02:39<32:28, 28.24s/it]{'hidden_layer_sizes': 6} 0.9731225296442687
#   9%|▉         | 7/75 [03:01<29:56, 26.42s/it]{'hidden_layer_sizes': (2, 5)} 0.9818181818181818
#  11%|█         | 8/75 [03:36<32:22, 29.00s/it]{'hidden_layer_sizes': (8, 2)} 0.990909090909091
#  12%|█▏        | 9/75 [04:08<33:10, 30.16s/it]{'hidden_layer_sizes': (8, 1)} 0.9818181818181818
#  13%|█▎        | 10/75 [04:31<30:11, 27.86s/it]{'hidden_layer_sizes': (2, 1)} 0.9735177865612649
#  15%|█▍        | 11/75 [04:53<27:46, 26.03s/it]{'hidden_layer_sizes': (8, 3)} 0.982213438735178
#  16%|█▌        | 12/75 [05:17<26:34, 25.31s/it]{'hidden_layer_sizes': 7} 0.982213438735178
#  17%|█▋        | 13/75 [05:40<25:22, 24.55s/it]{'hidden_layer_sizes': (3, 1)} 0.9735177865612649
#  19%|█▊        | 14/75 [06:01<24:05, 23.69s/it]{'hidden_layer_sizes': (7, 7)} 0.9818181818181818
#  20%|██        | 15/75 [06:24<23:15, 23.26s/it]{'hidden_layer_sizes': (2, 4)} 0.9822134387351777
#  21%|██▏       | 16/75 [06:47<23:01, 23.41s/it]{'hidden_layer_sizes': (4, 3)} 0.9735177865612649
#  96%|█████████▌| 72/75 [28:37<01:12, 24.09s/it]{'hidden_layer_sizes': (4, 3)} 0.9822134387351777
#  97%|█████████▋| 73/75 [29:00<00:47, 23.72s/it]{'hidden_layer_sizes': 12} 0.982213438735178
#  99%|█████████▊| 74/75 [29:23<00:23, 23.39s/it]{'hidden_layer_sizes': (6, 2)} 0.9818181818181818
# 100%|██████████| 75/75 [29:44<00:00, 23.79s/it]{'hidden_layer_sizes': (7, 7)} 0.9818181818181818

# %% [markdown]
# # Trovare i metaparametri che sono piu` spesso i migliori

# %%
oneLayer= dict()
twoLayer=dict()
for p, _ in params:
    n = p['hidden_layer_sizes']

    if isinstance(n, tuple):
        n = str(n)
        if n in twoLayer.keys():
            twoLayer[n]+=1
        else:
            twoLayer[n] = 1
    else:
        n = str(n)
        if n in oneLayer.keys():
            oneLayer[n]+=1
        else:
            oneLayer[n] = 1


plt.figure(figsize=(30, 3))  # width:20, height:3
plt.bar(*zip(*oneLayer.items()))
plt.bar(*zip(*twoLayer.items()))
plt.xticks(list(oneLayer.keys()) + list(twoLayer.keys()))
plt.show()

# %%
activations= dict()
for p, _ in params:
    n = p['activation']
    # if p['hidden_layer_sizes'] != 5:
    #     continue
    if n in activations:
        activations[n] +=1
    else:
        activations[n] = 1

plt.bar(*zip(*activations.items()))
plt.xticks(list(activations.keys()))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-7655eafd52ec> in <module>
#       2 activations= dict()
#       3 for p, _ in params:
# ----> 4     n = p['activation']
#       5     # if p['hidden_layer_sizes'] != 5:
#       6     #     continue
#
# KeyError: 'activation'

# %% [markdown]
# # Trovare i parametri che hanno l'accuratezza media piu` alta

# %%
oneLayer= dict()
twoLayer=dict()

for p, s in params:
    n = p['hidden_layer_sizes']

    if isinstance(n, tuple):
        n = str(n)
        if n in twoLayer.keys():
            twoLayer[n].append(s)
        else:
            twoLayer[n]=[s]
    else:
        n = str(n)
        if n in oneLayer.keys():
            oneLayer[n].append(s)
        else:
            oneLayer[n] = [s]




plt.figure(figsize=(30, 3))  # width:20, height:3
plt.bar(*zip(*[(k, sum(v)/len(v)-0.97) for k, v in oneLayer.items()]), bottom=0.97)
plt.bar(*zip(*[(k, sum(v)/len(v)-0.97) for k, v in twoLayer.items()]), bottom=0.97)
plt.xticks(list(oneLayer.keys()) + list(twoLayer.keys()))
plt.show()

# %%
activations = dict()
for p, s in params:
    p = p['activation']
    if p in activations:
        activations[p].append(s)
    else:
        activations[p] = [s]

x, y = [], []
for k, e in activations.items():
    x.append(k)
    y.append(sum(e)/len(e) - 0.96)

plt.figure(figsize=(20, 3))  # width:20, height:3
plt.bar(x,y, bottom=0.96)


plt.xticks(list(activations.keys()))
plt.show()

# %% [markdown]
# # Test configurazione

# %%
classifier = MLPClassifier(
                activation='tanh', hidden_layer_sizes=10,
                solver='adam', max_iter=500,
                )
from sklearn.metrics import confusion_matrix
classifier.fit(X_train, y_train)
c_matrix = confusion_matrix(y_test, classifier.predict(X_test))

print(c_matrix)
print(f"sensibilità = {c_matrix[1][1]/sum(c_matrix[1]):.3f}")
print(f"specificità = {c_matrix[0][0]/sum(c_matrix[0]):.3f}")
print(f"accuratezza = {classifier.score(X_test, y_test):.3f}")
