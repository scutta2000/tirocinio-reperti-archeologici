# %%
import sys; sys.path.insert(0, '..')

# %%
import scripts.get_data as gd
from sklearn.manifold import TSNE
from matplotlib import pyplot as plt
import pandas as pd

# %%
# X, y = gd.ceramiche_DB()
X, y= gd.da_classificare_DB(), 'orange'

tsne = TSNE().fit_transform(X)


plt.scatter(*zip(*tsne), c=y)

# %%
data = pd.read_excel('../dati_ceramiche_classificati.xlsx')
X = data.iloc()[:, 3:12]
y = round(data['media'])

tsne = TSNE().fit_transform(X)


plt.scatter(*zip(*tsne), c=y)
